# %%
import cfbd
from cfbd.rest import ApiException
from pprint import pprint

configuration = cfbd.Configuration()
configuration.api_key['Authorization'] = '3WCU5V2X05Rvh60ZxUG8FarJN4s2D1lcd2c2r6Kz/qL1Y3tVBJtWsuNATnzHRV2h'
configuration.api_key_prefix['Authorization'] = 'Bearer'

# %% [markdown]
# ##

# %%
api_instance = cfbd.GamesApi(cfbd.ApiClient(configuration))
year=2022
division="fbs"

try:
    # Betting lines
    api_response = api_instance.get_games(year=year,division=division)
    pprint(api_response)
except ApiException as e:
    print("Exception when calling BettingApi->get_lines: %s\n" % e)
# Out:
# [{'attendance': None,
#  'away_conference': 'Atlantic Sun',
#  'away_division': 'fcs',
#  'away_id': 2046,
#  'away_line_scores': [10, 7, 3, 7],
#  'away_points': 27,
#  'away_post_win_prob': 0.04572357337737354,
#  'away_postgame_elo': None,
#  'away_pregame_elo': None,
#  'away_team': 'Austin Peay',
#  'completed': True,
#  'conference_game': False,
#  'excitement_index': 2.6135509766,
#  'highlights': None,
#  'home_conference': 'Conference USA',
#  'home_division': 'fbs',
#  'home_id': 98,
#  'home_line_scores': [7, 14, 0, 17],
#  'home_points': 38,
#  'home_post_win_prob': 0.9542764266226265,
#  'home_postgame_elo': 1684,
#  'home_pregame_elo': 1684,
#  'home_team': 'Western Kentucky',
#  'id': 401426532,
#  'neutral_site': False,
#  'notes': None,
#  'season': 2022,
#  'season_type': 'regular',
#  'start_date': '2022-08-27T16:00:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'Houchens Industries-L. T. Smith Stadium',
#  'venue_id': 3796,
#  'week': 1},
#  {'attendance': None,
#  'away_conference': 'Big Ten',
#  'away_division': 'fbs',
#  'away_id': 158,
#  'away_line_scores': [7, 7, 14, 0],
#  'away_points': 28,
#  'away_post_win_prob': 0.45245654026480564,
#  'away_postgame_elo': 1616,
#  'away_pregame_elo': 1636,
#  'away_team': 'Nebraska',
#  'completed': True,
#  'conference_game': True,
#  'excitement_index': 8.3493556676,
#  'highlights': None,
#  'home_conference': 'Big Ten',
#  'home_division': 'fbs',
#  'home_id': 77,
#  'home_line_scores': [3, 14, 7, 7],
#  'home_points': 31,
#  'home_post_win_prob': 0.5475434597351944,
#  'home_postgame_elo': 1381,
#  'home_pregame_elo': 1361,
#  'home_team': 'Northwestern',
#  'id': 401405059,
#  'neutral_site': True,
#  'notes': None,
#  'season': 2022,
#  'season_type': 'regular',
#  'start_date': '2022-08-27T16:30:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'Aviva Stadium',
#  'venue_id': 3504,
#  'week': 1},
#  {'attendance': None,
#  'away_conference': 'Big Sky',
#  'away_division': 'fcs',
#  'away_id': 304,
#  'away_line_scores': [7, 0, 7, 7],
#  'away_points': 21,
#  'away_post_win_prob': None,
#  'away_postgame_elo': None,
#  'away_pregame_elo': None,
#  'away_team': 'Idaho State',
#  'completed': True,
#  'conference_game': False,
#  'excitement_index': None,
#  'highlights': None,
#  'home_conference': 'Mountain West',
#  'home_division': 'fbs',
#  'home_id': 2439,
#  'home_line_scores': [10, 35, 0, 7],
#  'home_points': 52,
#  'home_post_win_prob': None,
#  'home_postgame_elo': 1300,
#  'home_pregame_elo': 1300,
#  'home_team': 'UNLV',
#  'id': 401413256,
#  'neutral_site': False,
#  'notes': None,
#  'season': 2022,
#  'season_type': 'regular',
#  'start_date': '2022-08-27T19:30:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'Allegiant Stadium',
#  'venue_id': 6501,
#  'week': 1},
#  {'attendance': None,
#  'away_conference': 'FBS Independents',
#  'away_division': 'fbs',
#  'away_id': 41,
#  'away_line_scores': [14, 0, 0, 6],
#  'away_points': 20,
#  'away_post_win_prob': 0.010834414292027916,
#  'away_postgame_elo': 1128,
#  'away_pregame_elo': 1117,
#  'away_team': 'Connecticut',
#  'completed': True,
#  'conference_game': False,
#  'excitement_index': 4.5637067523,
#  'highlights': None,
#  'home_conference': 'Mountain West',
#  'home_division': 'fbs',
#  'home_id': 328,
#  'home_line_scores': [0, 24, 0, 7],
#  'home_points': 31,
#  'home_post_win_prob': 0.9891655857079721,
#  'home_postgame_elo': 1555,
#  'home_pregame_elo': 1566,
#  'home_team': 'Utah State',
#  'id': 401404146,
#  'neutral_site': False,
#  'notes': None,
#  'season': 2022,
#  'season_type': 'regular',
#  'start_date': '2022-08-27T20:00:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'Romney Stadium',
#  'venue_id': 3905,
#  'week': 1},
#  {'attendance': None,
#  'away_conference': 'Mountain West',
#  'away_division': 'fbs',
#  'away_id': 2751,
#  'away_line_scores': [3, 0, 3, 0],
#  'away_points': 6,
#  'away_post_win_prob': 0.0025277087946428134,
#  'away_postgame_elo': 1409,
#  'away_pregame_elo': 1497,
#  'away_team': 'Wyoming',
#  'completed': True,
#  'conference_game': False,
#  'excitement_index': 2.571416914,
#  'highlights': None,
#  'home_conference': 'Big Ten',
#  'home_division': 'fbs',
#  'home_id': 356,
#  'home_line_scores': [7, 10, 7, 14],
#  'home_points': 38,
#  'home_post_win_prob': 0.9974722912053572,
#  'home_postgame_elo': 1584,
#  'home_pregame_elo': 1496,
#  'home_team': 'Illinois',
#  'id': 401405058,
#  'neutral_site': False,
#  'notes': None,
#  'season': 2022,
#  'season_type': 'regular',
#  'start_date': '2022-08-27T20:00:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'Memorial Stadium',
#  'venue_id': 3832,
#  'week': 1},
#  {'attendance': None,
#  'away_conference': 'NEC',
#  'away_division': 'fcs',
#  'away_id': 2184,
#  'away_line_scores': [0, 0, 7, 0],
#  'away_points': 7,
#  'away_post_win_prob': 0.001057792030546234,
#  'away_postgame_elo': None,
#  'away_pregame_elo': None,
#  'away_team': 'Duquesne',
#  'completed': True,
#  'conference_game': False,
#  'excitement_index': 1.058953588,
#  'highlights': None,
#  'home_conference': 'ACC',
#  'home_division': 'fbs',
#  'home_id': 52,
#  'home_line_scores': [20, 6, 14, 7],
#  'home_points': 47,
#  'home_post_win_prob': 0.9989422079694538,
#  'home_postgame_elo': 1501,
#  'home_pregame_elo': 1501,
#  'home_team': 'Florida State',
#  'id': 401411090,
#  'neutral_site': False,
#  'notes': None,
#  'season': 2022,
#  'season_type': 'regular',
#  'start_date': '2022-08-27T21:00:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'Bobby Bowden Field at Doak Campbell Stadium',
#  'venue_id': 3697,
#  'week': 1},
#  {'attendance': None,
#  'away_conference': 'Conference USA',
#  'away_division': 'fbs',
#  'away_id': 2429,
#  'away_line_scores': [7, 0, 6, 0],
#  'away_points': 13,
#  'away_post_win_prob': 0.0011584457822981786,
#  'away_postgame_elo': 1211,
#  'away_pregame_elo': 1272,
#  'away_team': 'Charlotte',
#  'completed': True,
#  'conference_game': True,
#  'excitement_index': 6.6262524505,
#  'highlights': None,
#  'home_conference': 'Conference USA',
#  'home_division': 'fbs',
#  'home_id': 2226,
#  'home_line_scores': [10, 16, 7, 10],
#  'home_points': 43,
#  'home_post_win_prob': 0.9988415542177018,
#  'home_postgame_elo': 1488,
#  'home_pregame_elo': 1427,
#  'home_team': 'Florida Atlantic',
#  'id': 401426530,
#  'neutral_site': False,
#  'notes': None,
#  'season': 2022,
#  'season_type': 'regular',
#  'start_date': '2022-08-27T23:00:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'FAU Stadium',
#  'venue_id': 3715,
#  'week': 1},
#  {'attendance': None,
#  'away_conference': 'SWAC',
#  'away_division': 'fcs',
#  'away_id': 50,
#  'away_line_scores': [7, 7, 10, 0],
#  'away_points': 24,
#  'away_post_win_prob': 0.03629921926267887,
#  'away_postgame_elo': None,
#  'away_pregame_elo': None,
#  'away_team': 'Florida A&M',
#  'completed': True,
#  'conference_game': False,
#  'excitement_index': 1.2411118443,
#  'highlights': None,
#  'home_conference': 'ACC',
#  'home_division': 'fbs',
#  'home_id': 153,
#  'home_line_scores': [14, 14, 7, 21],
#  'home_points': 56,
#  'home_post_win_prob': 0.9637007807373211,
#  'home_postgame_elo': 1555,
#  'home_pregame_elo': 1555,
#  'home_team': 'North Carolina',
#  'id': 401411091,
#  'neutral_site': False,
#  'notes': None,
#  'season': 2022,
#  'season_type': 'regular',
#  'start_date': '2022-08-28T00:15:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'Kenan Memorial Stadium',
#  'venue_id': 3787,
#  'week': 1},
#  {'attendance': None,
#  'away_conference': 'Conference USA',
#  'away_division': 'fbs',
#  'away_id': 249,
#  'away_line_scores': [0, 14, 14, 3],
#  'away_points': 31,
#  'away_post_win_prob': 0.9952536646437844,
#  'away_postgame_elo': 1463,
#  'away_pregame_elo': 1426,
#  'away_team': 'North Texas',
#  'completed': True,
#  'conference_game': True,
#  'excitement_index': 4.1152955946,
#  'highlights': None,
#  'home_conference': 'Conference USA',
#  'home_division': 'fbs',
#  'home_id': 2638,
#  'home_line_scores': [0, 13, 0, 0],
#  'home_points': 13,
#  'home_post_win_prob': 0.004746335356215618,
#  'home_postgame_elo': 1323,
#  'home_pregame_elo': 1360,
#  'home_team': 'UTEP',
#  'id': 401426531,
#  'neutral_site': False,
#  'notes': None,
#  'season': 2022,
#  'season_type': 'regular',
#  'start_date': '2022-08-28T01:00:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'Sun Bowl Stadium',
#  'venue_id': 3946,
#  'week': 1},
#  {'attendance': None,
#  'away_conference': 'Mountain West',
#  'away_division': 'fbs',
#  'away_id': 2440,
#  'away_line_scores': [0, 17, 0, 6],
#  'away_points': 23,
#  'away_post_win_prob': 0.865630293812243,
#  'away_postgame_elo': 1556,
#  'away_pregame_elo': 1564,
#  'away_team': 'Nevada',
#  'completed': True,
#  'conference_game': False,
#  'excitement_index': 3.8315877915,
#  'highlights': None,
#  'home_conference': 'FBS Independents',
#  'home_division': 'fbs',
#  'home_id': 166,
#  'home_line_scores': [0, 2, 7, 3],
#  'home_points': 12,
#  'home_post_win_prob': 0.13436970618775704,
#  'home_postgame_elo': 1192,
#  'home_pregame_elo': 1184,
#  'home_team': 'New Mexico State',
#  'id': 401409235,
#  'neutral_site': False,
#  'notes': None,
#  'season': 2022,
#  'season_type': 'regular',
#  'start_date': '2022-08-28T02:00:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'Aggie Memorial Stadium',
#  'venue_id': 3601,
#  'week': 1},
#  {'attendance': None,
#  'away_conference': 'SEC',
#  'away_division': 'fbs',
#  'away_id': 238,
#  'away_line_scores': [14, 7, 35, 7],
#  'away_points': 63,
#  'away_post_win_prob': 0.9996410399011048,
#  'away_postgame_elo': 1431,
#  'away_pregame_elo': 1222,
#  'away_team': 'Vanderbilt',
#  'completed': True,
#  'conference_game': False,
#  'excitement_index': 2.4199370723,
#  'highlights': None,
#  'home_conference': 'Mountain West',
#  'home_division': 'fbs',
#  'home_id': 62,
#  'home_line_scores': [7, 3, 0, 0],
#  'home_points': 10,
#  'home_post_win_prob': 0.0003589600988952661,
#  'home_postgame_elo': 1223,
#  'home_pregame_elo': 1432,
#  'home_team': "Hawai'i",
#  'id': 401403853,
#  'neutral_site': False,
#  'notes': None,
#  'season': 2022,
#  'season_type': 'regular',
#  'start_date': '2022-08-28T02:30:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'Clarence T.C. Ching Athletics Complex',
#  'venue_id': 7220,
#  'week': 1},
#  {'attendance': None,
#  'away_conference': 'NEC',
#  'away_division': 'fcs',
#  'away_id': 2598,
#  'away_line_scores': [3, 10, 3, 7, 0],
#  'away_points': 23,
#  'away_post_win_prob': 0.8474613227445974,
#  'away_postgame_elo': None,
#  'away_pregame_elo': None,
#  'away_team': 'St Francis (PA)',
#  'completed': True,
#  'conference_game': False,
#  'excitement_index': 12.0273396679,
#  'highlights': None,
#  'home_conference': 'Mid-American',
#  'home_division': 'fbs',
#  'home_id': 2006,
#  'home_line_scores': [3, 7, 7, 6, 7],
#  'home_points': 30,
#  'home_post_win_prob': 0.1525386772554026,
#  'home_postgame_elo': 1096,
#  'home_pregame_elo': 1096,
#  'home_team': 'Akron',
#  'id': 401416568,
#  'neutral_site': False,
#  'notes': None,
#  'season': 2022,
#  'season_type': 'regular',
#  'start_date': '2022-09-01T22:00:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'Summa Field at InfoCision Stadium',
#  'venue_id': 3768,
#  'week': 1},
#  {'attendance': None,
#  'away_conference': 'Big South',
#  'away_division': 'fcs',
#  'away_id': 2803,
#  'away_line_scores': [9, 7, 0, 14, 7],
#  'away_points': 37,
#  'away_post_win_prob': 0.5928593061799015,
#  'away_postgame_elo': None,
#  'away_pregame_elo': None,
#  'away_team': 'Bryant',
#  'completed': True,
#  'conference_game': False,
#  'excitement_index': 12.8939729771,
#  'highlights': None,
#  'home_conference': 'Conference USA',
#  'home_division': 'fbs',
#  'home_id': 2229,
#  'home_line_scores': [0, 6, 0, 24, 8],
#  'home_points': 38,
#  'home_post_win_prob': 0.4071406938200985,
#  'home_postgame_elo': 1080,
#  'home_pregame_elo': 1080,
#  'home_team': 'Florida International',
#  'id': 401426533,
#  'neutral_site': False,
#  'notes': None,
#  'season': 2022,
#  'season_type': 'regular',
#  'start_date': '2022-09-01T23:00:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'FIU Stadium',
#  'venue_id': 218,
#  'week': 1},
#  {'attendance': None,
#  'away_conference': 'MEAC',
#  'away_division': 'fcs',
#  'away_id': 2569,
#  'away_line_scores': [0, 3, 7, 0],
#  'away_points': 10,
#  'away_post_win_prob': None,
#  'away_postgame_elo': None,
#  'away_pregame_elo': None,
#  'away_team': 'South Carolina State',
#  'completed': True,
#  'conference_game': False,
#  'excitement_index': None,
#  'highlights': None,
#  'home_conference': 'American Athletic',
#  'home_division': 'fbs',
#  'home_id': 2116,
#  'home_line_scores': [21, 7, 14, 14],
#  'home_points': 56,
#  'home_post_win_prob': None,
#  'home_postgame_elo': 1569,
#  'home_pregame_elo': 1569,
#  'home_team': 'UCF',
#  'id': 401415610,
#  'neutral_site': False,
#  'notes': None,
#  'season': 2022,
#  'season_type': 'regular',
#  'start_date': '2022-09-01T23:00:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'Bright House Networks Stadium',
#  'venue_id': 3652,
#  'week': 1},
#  {'attendance': None,
#  'away_conference': 'Mid-American',
#  'away_division': 'fbs',
#  'away_id': 2050,
#  'away_line_scores': [0, 0, 7, 3],
#  'away_points': 10,
#  'away_post_win_prob': 0.0015806069051993443,
#  'away_postgame_elo': 1294,
#  'away_pregame_elo': 1410,
#  'away_team': 'Ball State',
#  'completed': True,
#  'conference_game': False,
#  'excitement_index': 1.1199358518,
#  'highlights': None,
#  'home_conference': 'SEC',
#  'home_division': 'fbs',
#  'home_id': 2633,
#  'home_line_scores': [17, 21, 14, 7],
#  'home_points': 59,
#  'home_post_win_prob': 0.9984193930948007,
#  'home_postgame_elo': 1756,
#  'home_pregame_elo': 1640,
#  'home_team': 'Tennessee',
#  'id': 401403864,
#  'neutral_site': False,
#  'notes': None,
#  'season': 2022,
#  'season_type': 'regular',
#  'start_date': '2022-09-01T23:00:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'Neyland Stadium',
#  'venue_id': 3853,
#  'week': 1},
#  {'attendance': None,
#  'away_conference': 'NEC',
#  'away_division': 'fcs',
#  'away_id': 112358,
#  'away_line_scores': [0, 0, 0, 0],
#  'away_points': 0,
#  'away_post_win_prob': 0.006518984596762145,
#  'away_postgame_elo': None,
#  'away_pregame_elo': None,
#  'away_team': 'Long Island University',
#  'completed': True,
#  'conference_game': False,
#  'excitement_index': 1.1696927417,
#  'highlights': None,
#  'home_conference': 'Mid-American',
#  'home_division': 'fbs',
#  'home_id': 2649,
#  'home_line_scores': [3, 17, 0, 17],
#  'home_points': 37,
#  'home_post_win_prob': 0.9934810154032379,
#  'home_postgame_elo': 1534,
#  'home_pregame_elo': 1534,
#  'home_team': 'Toledo',
#  'id': 401441990,
#  'neutral_site': False,
#  'notes': None,
#  'season': 2022,
#  'season_type': 'regular',
#  'start_date': '2022-09-01T23:00:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'Glass Bowl',
#  'venue_id': 3739,
#  'week': 1},
#  {'attendance': None,
#  'away_conference': 'Big 12',
#  'away_division': 'fbs',
#  'away_id': 277,
#  'away_line_scores': [0, 10, 7, 14],
#  'away_points': 31,
#  'away_post_win_prob': 0.013402669549195445,
#  'away_postgame_elo': 1490,
#  'away_pregame_elo': 1490,
#  'away_team': 'West Virginia',
#  'completed': True,
#  'conference_game': False,
#  'excitement_index': 9.9132290774,
#  'highlights': None,
#  'home_conference': 'ACC',
#  'home_division': 'fbs',
#  'home_id': 221,
#  'home_line_scores': [3, 7, 14, 14],
#  'home_points': 38,
#  'home_post_win_prob': 0.9865973304508046,
#  'home_postgame_elo': 1667,
#  'home_pregame_elo': 1667,
#  'home_team': 'Pittsburgh',
#  'id': 401411092,
#  'neutral_site': False,
#  'notes': None,
#  'season': 2022,
#  'season_type': 'regular',
#  'start_date': '2022-09-01T23:00:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'Heinz Field',
#  'venue_id': 3752,
#  'week': 1},
#  {'attendance': None,
#  'away_conference': 'Mid-American',
#  'away_division': 'fbs',
#  'away_id': 2117,
#  'away_line_scores': [7, 8, 7, 22],
#  'away_points': 44,
#  'away_post_win_prob': 0.39939073388751034,
#  'away_postgame_elo': 1528,
#  'away_pregame_elo': 1536,
#  'away_team': 'Central Michigan',
#  'completed': True,
#  'conference_game': False,
#  'excitement_index': 2.0476622516,
#  'highlights': None,
#  'home_conference': 'Big 12',
#  'home_division': 'fbs',
#  'home_id': 197,
#  'home_line_scores': [16, 28, 7, 7],
#  'home_points': 58,
#  'home_post_win_prob': 0.6006092661124897,
#  'home_postgame_elo': 1783,
#  'home_pregame_elo': 1775,
#  'home_team': 'Oklahoma State',
#  'id': 401416569,
#  'neutral_site': False,
#  'notes': None,
#  'season': 2022,
#  'season_type': 'regular',
#  'start_date': '2022-09-01T23:00:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'Boone Pickens Stadium',
#  'venue_id': 3646,
#  'week': 1},
#  {'attendance': None,
#  'away_conference': 'Southern',
#  'away_division': 'fcs',
#  'away_id': 2678,
#  'away_line_scores': [0, 3, 7, 0],
#  'away_points': 10,
#  'away_post_win_prob': 0.0029952575536539294,
#  'away_postgame_elo': None,
#  'away_pregame_elo': None,
#  'away_team': 'VMI',
#  'completed': True,
#  'conference_game': False,
#  'excitement_index': 1.2759959221,
#  'highlights': None,
#  'home_conference': 'ACC',
#  'home_division': 'fbs',
#  'home_id': 154,
#  'home_line_scores': [17, 6, 14, 7],
#  'home_points': 44,
#  'home_post_win_prob': 0.9970047424463461,
#  'home_postgame_elo': 1640,
#  'home_pregame_elo': 1640,
#  'home_team': 'Wake Forest',
#  'id': 401411093,
#  'neutral_site': False,
#  'notes': None,
#  'season': 2022,
#  'season_type': 'regular',
#  'start_date': '2022-09-01T23:30:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'BB&T Field',
#  'venue_id': 3630,
#  'week': 1},
#  {'attendance': None,
#  'away_conference': 'SWAC',
#  'away_division': 'fcs',
#  'away_id': 2010,
#  'away_line_scores': [0, 0, 0, 0],
#  'away_points': 0,
#  'away_post_win_prob': 0.0010596173839598766,
#  'away_postgame_elo': None,
#  'away_pregame_elo': None,
#  'away_team': 'Alabama A&M',
#  'completed': True,
#  'conference_game': False,
#  'excitement_index': 1.0305953775,
#  'highlights': None,
#  'home_conference': 'Conference USA',
#  'home_division': 'fbs',
#  'home_id': 5,
#  'home_line_scores': [28, 10, 21, 0],
#  'home_points': 59,
#  'home_post_win_prob': 0.9989403826160401,
#  'home_postgame_elo': 1546,
#  'home_pregame_elo': 1546,
#  'home_team': 'UAB',
#  'id': 401426534,
#  'neutral_site': False,
#  'notes': None,
#  'season': 2022,
#  'season_type': 'regular',
#  'start_date': '2022-09-02T00:00:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'Protective Stadium',
#  'venue_id': 7221,
#  'week': 1},
#  {'attendance': None,
#  'away_conference': 'OVC',
#  'away_division': 'fcs',
#  'away_id': 2197,
#  'away_line_scores': [3, 3, 7, 14],
#  'away_points': 27,
#  'away_post_win_prob': 0.5574376840541737,
#  'away_postgame_elo': None,
#  'away_pregame_elo': None,
#  'away_team': 'Eastern Illinois',
#  'completed': True,
#  'conference_game': False,
#  'excitement_index': 1.4468880733,
#  'highlights': None,
#  'home_conference': 'Mid-American',
#  'home_division': 'fbs',
#  'home_id': 2459,
#  'home_line_scores': [7, 14, 7, 6],
#  'home_points': 34,
#  'home_post_win_prob': 0.4425623159458263,
#  'home_postgame_elo': 1376,
#  'home_pregame_elo': 1376,
#  'home_team': 'Northern Illinois',
#  'id': 401416592,
#  'neutral_site': False,
#  'notes': None,
#  'season': 2022,
#  'season_type': 'regular',
#  'start_date': '2022-09-02T00:00:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'Brigham Field at Huskie Stadium',
#  'venue_id': 3764,
#  'week': 1},
#  {'attendance': None,
#  'away_conference': 'Big Ten',
#  'away_division': 'fbs',
#  'away_id': 213,
#  'away_line_scores': [0, 21, 0, 14],
#  'away_points': 35,
#  'away_post_win_prob': 0.5149394854165616,
#  'away_postgame_elo': 1674,
#  'away_pregame_elo': 1670,
#  'away_team': 'Penn State',
#  'completed': True,
#  'conference_game': True,
#  'excitement_index': 9.5688027282,
#  'highlights': None,
#  'home_conference': 'Big Ten',
#  'home_division': 'fbs',
#  'home_id': 2509,
#  'home_line_scores': [3, 7, 14, 7],
#  'home_points': 31,
#  'home_post_win_prob': 0.48506051458343835,
#  'home_postgame_elo': 1631,
#  'home_pregame_elo': 1635,
#  'home_team': 'Purdue',
#  'id': 401405064,
#  'neutral_site': False,
#  'notes': None,
#  'season': 2022,
#  'season_type': 'regular',
#  'start_date': '2022-09-02T00:00:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'Ross-Ade Stadium',
#  'venue_id': 3907,
#  'week': 1},
#  {'attendance': None,
#  'away_conference': 'Conference USA',
#  'away_division': 'fbs',
#  'away_id': 2348,
#  'away_line_scores': [3, 7, 0, 14],
#  'away_points': 24,
#  'away_post_win_prob': 0.004638669738315948,
#  'away_postgame_elo': 1240,
#  'away_pregame_elo': 1301,
#  'away_team': 'Louisiana Tech',
#  'completed': True,
#  'conference_game': False,
#  'excitement_index': 2.5195936354,
#  'highlights': None,
#  'home_conference': 'SEC',
#  'home_division': 'fbs',
#  'home_id': 142,
#  'home_line_scores': [0, 24, 14, 14],
#  'home_points': 52,
#  'home_post_win_prob': 0.995361330261684,
#  'home_postgame_elo': 1465,
#  'home_pregame_elo': 1404,
#  'home_team': 'Missouri',
#  'id': 401426537,
#  'neutral_site': False,
#  'notes': None,
#  'season': 2022,
#  'season_type': 'regular',
#  'start_date': '2022-09-02T00:00:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'Faurot Field',
#  'venue_id': 3838,
#  'week': 1},
#  {'attendance': None,
#  'away_conference': 'FBS Independents',
#  'away_division': 'fbs',
#  'away_id': 166,
#  'away_line_scores': [0, 0, 0, 0],
#  'away_points': 0,
#  'away_post_win_prob': 0.0010418388876689555,
#  'away_postgame_elo': 1140,
#  'away_pregame_elo': 1192,
#  'away_team': 'New Mexico State',
#  'completed': True,
#  'conference_game': False,
#  'excitement_index': 1.1471103779,
#  'highlights': None,
#  'home_conference': 'Big Ten',
#  'home_division': 'fbs',
#  'home_id': 135,
#  'home_line_scores': [7, 17, 14, 0],
#  'home_points': 38,
#  'home_post_win_prob': 0.998958161112331,
#  'home_postgame_elo': 1691,
#  'home_pregame_elo': 1639,
#  'home_team': 'Minnesota',
#  'id': 401405060,
#  'neutral_site': False,
#  'notes': None,
#  'season': 2022,
#  'season_type': 'regular',
#  'start_date': '2022-09-02T01:00:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'TCF Bank Stadium',
#  'venue_id': 3953,
#  'week': 1},
#  {'attendance': None,
#  'away_conference': 'Big Sky',
#  'away_division': 'fcs',
#  'away_id': 2464,
#  'away_line_scores': [0, 3, 0, 0],
#  'away_points': 3,
#  'away_post_win_prob': None,
#  'away_postgame_elo': None,
#  'away_pregame_elo': None,
#  'away_team': 'Northern Arizona',
#  'completed': True,
#  'conference_game': False,
#  'excitement_index': None,
#  'highlights': None,
#  'home_conference': 'Pac-12',
#  'home_division': 'fbs',
#  'home_id': 9,
#  'home_line_scores': [3, 21, 13, 3],
#  'home_points': 40,
#  'home_post_win_prob': None,
#  'home_postgame_elo': 1614,
#  'home_pregame_elo': 1614,
#  'home_team': 'Arizona State',
#  'id': 401403965,
#  'neutral_site': False,
#  'notes': None,
#  'season': 2022,
#  'season_type': 'regular',
#  'start_date': '2022-09-02T02:00:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'Sun Devil Stadium',
#  'venue_id': 3947,
#  'week': 1},
#  {'attendance': None,
#  'away_conference': 'Big Sky',
#  'away_division': 'fcs',
#  'away_id': 13,
#  'away_line_scores': [0, 7, 0, 0],
#  'away_points': 7,
#  'away_post_win_prob': 0.0011436056579916531,
#  'away_postgame_elo': None,
#  'away_pregame_elo': None,
#  'away_team': 'Cal Poly',
#  'completed': True,
#  'conference_game': False,
#  'excitement_index': 1.1488744416,
#  'highlights': None,
#  'home_conference': 'Mountain West',
#  'home_division': 'fbs',
#  'home_id': 278,
#  'home_line_scores': [21, 0, 7, 7],
#  'home_points': 35,
#  'home_post_win_prob': 0.9988563943420083,
#  'home_postgame_elo': 1590,
#  'home_pregame_elo': 1590,
#  'home_team': 'Fresno State',
#  'id': 401413224,
#  'neutral_site': False,
#  'notes': None,
#  'season': 2022,
#  'season_type': 'regular',
#  'start_date': '2022-09-02T02:30:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'Bulldog Stadium',
#  'venue_id': 3660,
#  'week': 1},
#  {'attendance': None,
#  'away_conference': 'Big Sky',
#  'away_division': 'fcs',
#  'away_id': 2502,
#  'away_line_scores': [7, 0, 3, 7],
#  'away_points': 17,
#  'away_post_win_prob': 0.9909738758309266,
#  'away_postgame_elo': None,
#  'away_pregame_elo': None,
#  'away_team': 'Portland State',
#  'completed': True,
#  'conference_game': False,
#  'excitement_index': 5.4525229031,
#  'highlights': None,
#  'home_conference': 'Mountain West',
#  'home_division': 'fbs',
#  'home_id': 23,
#  'home_line_scores': [7, 7, 0, 7],
#  'home_points': 21,
#  'home_post_win_prob': 0.00902612416907343,
#  'home_postgame_elo': 1338,
#  'home_pregame_elo': 1338,
#  'home_team': 'San José State',
#  'id': 401415213,
#  'neutral_site': False,
#  'notes': None,
#  'season': 2022,
#  'season_type': 'regular',
#  'start_date': '2022-09-02T02:30:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'Spartan Stadium',
#  'venue_id': 3935,
#  'week': 1},
#  {'attendance': None,
#  'away_conference': 'Atlantic Sun',
#  'away_division': 'fcs',
#  'away_id': 2198,
#  'away_line_scores': [0, 10, 7, 17],
#  'away_points': 34,
#  'away_post_win_prob': 0.34601383731962143,
#  'away_postgame_elo': None,
#  'away_pregame_elo': None,
#  'away_team': 'Eastern Kentucky',
#  'completed': True,
#  'conference_game': False,
#  'excitement_index': 6.3483908778,
#  'highlights': None,
#  'home_conference': 'Mid-American',
#  'home_division': 'fbs',
#  'home_id': 2199,
#  'home_line_scores': [0, 14, 14, 14],
#  'home_points': 42,
#  'home_post_win_prob': 0.6539861626803786,
#  'home_postgame_elo': 1380,
#  'home_pregame_elo': 1380,
#  'home_team': 'Eastern Michigan',
#  'id': 401416590,
#  'neutral_site': False,
#  'notes': None,
#  'season': 2022,
#  'season_type': 'regular',
#  'start_date': '2022-09-02T23:00:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'Rynearson Stadium',
#  'venue_id': 3912,
#  'week': 1},
#  {'attendance': None,
#  'away_conference': 'CAA',
#  'away_division': 'fcs',
#  'away_id': 2729,
#  'away_line_scores': [10, 7, 3, 21],
#  'away_points': 41,
#  'away_post_win_prob': 0.9495363986751971,
#  'away_postgame_elo': None,
#  'away_pregame_elo': None,
#  'away_team': 'William & Mary',
#  'completed': True,
#  'conference_game': False,
#  'excitement_index': 9.4100183239,
#  'highlights': None,
#  'home_conference': 'Conference USA',
#  'home_division': 'fbs',
#  'home_id': 2429,
#  'home_line_scores': [3, 14, 7, 0],
#  'home_points': 24,
#  'home_post_win_prob': 0.05046360132480283,
#  'home_postgame_elo': 1206,
#  'home_pregame_elo': 1206,
#  'home_team': 'Charlotte',
#  'id': 401426535,
#  'neutral_site': False,
#  'notes': None,
#  'season': 2022,
#  'season_type': 'regular',
#  'start_date': '2022-09-02T23:00:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'Jerry Richardson Stadium',
#  'venue_id': 4418,
#  'week': 1},
#  {'attendance': None,
#  'away_conference': 'ACC',
#  'away_division': 'fbs',
#  'away_id': 259,
#  'away_line_scores': [7, 0, 10, 0],
#  'away_points': 17,
#  'away_post_win_prob': 0.993763288475589,
#  'away_postgame_elo': 1411,
#  'away_pregame_elo': 1412,
#  'away_team': 'Virginia Tech',
#  'completed': True,
#  'conference_game': False,
#  'excitement_index': 9.2340782584,
#  'highlights': None,
#  'home_conference': 'Sun Belt',
#  'home_division': 'fbs',
#  'home_id': 295,
#  'home_line_scores': [0, 10, 0, 10],
#  'home_points': 20,
#  'home_post_win_prob': 0.006236711524411014,
#  'home_postgame_elo': 1391,
#  'home_pregame_elo': 1390,
#  'home_team': 'Old Dominion',
#  'id': 401426330,
#  'neutral_site': False,
#  'notes': None,
#  'season': 2022,
#  'season_type': 'regular',
#  'start_date': '2022-09-02T23:00:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'Foreman Field',
#  'venue_id': 3918,
#  'week': 1},
#  {'attendance': None,
#  'away_conference': 'Mid-American',
#  'away_division': 'fbs',
#  'away_id': 2711,
#  'away_line_scores': [3, 0, 10, 0],
#  'away_points': 13,
#  'away_post_win_prob': 0.019701391137356805,
#  'away_postgame_elo': 1488,
#  'away_pregame_elo': 1538,
#  'away_team': 'Western Michigan',
#  'completed': True,
#  'conference_game': False,
#  'excitement_index': 2.4084936095,
#  'highlights': None,
#  'home_conference': 'Big Ten',
#  'home_division': 'fbs',
#  'home_id': 127,
#  'home_line_scores': [7, 14, 0, 14],
#  'home_points': 35,
#  'home_post_win_prob': 0.9802986088626432,
#  'home_postgame_elo': 1613,
#  'home_pregame_elo': 1563,
#  'home_team': 'Michigan State',
#  'id': 401416591,
#  'neutral_site': False,
#  'notes': None,
#  'season': 2022,
#  'season_type': 'regular',
#  'start_date': '2022-09-02T23:00:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'Spartan Stadium',
#  'venue_id': 3936,
#  'week': 1},
#  {'attendance': None,
#  'away_conference': 'American Athletic',
#  'away_division': 'fbs',
#  'away_id': 218,
#  'away_line_scores': [0, 0, 0, 0],
#  'away_points': 0,
#  'away_post_win_prob': 0.0010748210175389739,
#  'away_postgame_elo': 1029,
#  'away_pregame_elo': 1101,
#  'away_team': 'Temple',
#  'completed': True,
#  'conference_game': False,
#  'excitement_index': 2.0028841548,
#  'highlights': None,
#  'home_conference': 'ACC',
#  'home_division': 'fbs',
#  'home_id': 150,
#  'home_line_scores': [10, 14, 3, 3],
#  'home_points': 30,
#  'home_post_win_prob': 0.998925178982461,
#  'home_postgame_elo': 1240,
#  'home_pregame_elo': 1168,
#  'home_team': 'Duke',
#  'id': 401411094,
#  'neutral_site': False,
#  'notes': None,
#  'season': 2022,
#  'season_type': 'regular',
#  'start_date': '2022-09-02T23:30:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'Wallace Wade Stadium',
#  'venue_id': 3982,
#  'week': 1},
#  {'attendance': None,
#  'away_conference': 'Big Ten',
#  'away_division': 'fbs',
#  'away_id': 356,
#  'away_line_scores': [7, 3, 7, 3],
#  'away_points': 20,
#  'away_post_win_prob': 0.8966231094377778,
#  'away_postgame_elo': 1579,
#  'away_pregame_elo': 1584,
#  'away_team': 'Illinois',
#  'completed': True,
#  'conference_game': True,
#  'excitement_index': 10.0629165175,
#  'highlights': None,
#  'home_conference': 'Big Ten',
#  'home_division': 'fbs',
#  'home_id': 84,
#  'home_line_scores': [3, 13, 0, 7],
#  'home_points': 23,
#  'home_post_win_prob': 0.10337689056222221,
#  'home_postgame_elo': 1335,
#  'home_pregame_elo': 1330,
#  'home_team': 'Indiana',
#  'id': 401405061,
#  'neutral_site': False,
#  'notes': None,
#  'season': 2022,
#  'season_type': 'regular',
#  'start_date': '2022-09-03T00:00:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'Memorial Stadium',
#  'venue_id': 3830,
#  'week': 1},
#  {'attendance': None,
#  'away_conference': 'OVC',
#  'away_division': 'fcs',
#  'away_id': 2635,
#  'away_line_scores': [0, 3, 0, 7],
#  'away_points': 10,
#  'away_post_win_prob': 0.0010603927804481161,
#  'away_postgame_elo': None,
#  'away_pregame_elo': None,
#  'away_team': 'Tennessee Tech',
#  'completed': True,
#  'conference_game': False,
#  'excitement_index': 1.1732355063,
#  'highlights': None,
#  'home_conference': 'Big 12',
#  'home_division': 'fbs',
#  'home_id': 2305,
#  'home_line_scores': [21, 14, 7, 14],
#  'home_points': 56,
#  'home_post_win_prob': 0.9989396072195519,
#  'home_postgame_elo': 1194,
#  'home_pregame_elo': 1194,
#  'home_team': 'Kansas',
#  'id': 401404052,
#  'neutral_site': False,
#  'notes': None,
#  'season': 2022,
#  'season_type': 'regular',
#  'start_date': '2022-09-03T00:00:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'Memorial Stadium',
#  'venue_id': 3833,
#  'week': 1},
#  {'attendance': None,
#  'away_conference': 'Big 12',
#  'away_division': 'fbs',
#  'away_id': 2628,
#  'away_line_scores': [0, 7, 10, 21],
#  'away_points': 38,
#  'away_post_win_prob': 0.9976395740093309,
#  'away_postgame_elo': 1497,
#  'away_pregame_elo': 1436,
#  'away_team': 'TCU',
#  'completed': True,
#  'conference_game': False,
#  'excitement_index': 3.1865666133,
#  'highlights': None,
#  'home_conference': 'Pac-12',
#  'home_division': 'fbs',
#  'home_id': 38,
#  'home_line_scores': [3, 3, 0, 7],
#  'home_points': 13,
#  'home_post_win_prob': 0.002360425990669103,
#  'home_postgame_elo': 1326,
#  'home_pregame_elo': 1387,
#  'home_team': 'Colorado',
#  'id': 401403966,
#  'neutral_site': False,
#  'notes': None,
#  'season': 2022,
#  'season_type': 'regular',
#  'start_date': '2022-09-03T02:00:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'Folsom Field',
#  'venue_id': 3726,
#  'week': 1},
#  {'attendance': None,
#  'away_conference': 'NEC',
#  'away_division': 'fcs',
#  'away_id': 2115,
#  'away_line_scores': [0, 3, 0, 0],
#  'away_points': 3,
#  'away_post_win_prob': 0.0015138345830116862,
#  'away_postgame_elo': None,
#  'away_pregame_elo': None,
#  'away_team': 'Central Connecticut',
#  'completed': True,
#  'conference_game': False,
#  'excitement_index': 3.3870174119,
#  'highlights': None,
#  'home_conference': 'FBS Independents',
#  'home_division': 'fbs',
#  'home_id': 41,
#  'home_line_scores': [0, 7, 7, 14],
#  'home_points': 28,
#  'home_post_win_prob': 0.9984861654169883,
#  'home_postgame_elo': 1117,
#  'home_pregame_elo': 1117,
#  'home_team': 'Connecticut',
#  'id': 401404147,
#  'neutral_site': False,
#  'notes': None,
#  'season': 2022,
#  'season_type': 'regular',
#  'start_date': '2022-09-03T16:00:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'Rentschler Field',
#  'venue_id': 3892,
#  'week': 1},
#  {'attendance': None,
#  'away_conference': 'ACC',
#  'away_division': 'fbs',
#  'away_id': 152,
#  'away_line_scores': [14, 7, 0, 0],
#  'away_points': 21,
#  'away_post_win_prob': 0.5374562457609533,
#  'away_postgame_elo': 1628,
#  'away_pregame_elo': 1632,
#  'away_team': 'NC State',
#  'completed': True,
#  'conference_game': False,
#  'excitement_index': 5.5237324644,
#  'highlights': None,
#  'home_conference': 'American Athletic',
#  'home_division': 'fbs',
#  'home_id': 151,
#  'home_line_scores': [7, 0, 7, 6],
#  'home_points': 20,
#  'home_post_win_prob': 0.46254375423904664,
#  'home_postgame_elo': 1522,
#  'home_pregame_elo': 1518,
#  'home_team': 'East Carolina',
#  'id': 401411096,
#  'neutral_site': False,
#  'notes': None,
#  'season': 2022,
#  'season_type': 'regular',
#  'start_date': '2022-09-03T16:00:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'Dowdy-Ficklen Stadium',
#  'venue_id': 3699,
#  'week': 1},
#  {'attendance': None,
#  'away_conference': 'ACC',
#  'away_division': 'fbs',
#  'away_id': 153,
#  'away_line_scores': [7, 21, 13, 22],
#  'away_points': 63,
#  'away_post_win_prob': 0.712707477620224,
#  'away_postgame_elo': 1563,
#  'away_pregame_elo': 1555,
#  'away_team': 'North Carolina',
#  'completed': True,
#  'conference_game': False,
#  'excitement_index': 4.6030352395,
#  'highlights': None,
#  'home_conference': 'Sun Belt',
#  'home_division': 'fbs',
#  'home_id': 2026,
#  'home_line_scores': [14, 7, 0, 40],
#  'home_points': 61,
#  'home_post_win_prob': 0.287292522379776,
#  'home_postgame_elo': 1648,
#  'home_pregame_elo': 1656,
#  'home_team': 'Appalachian State',
#  'id': 401411095,
#  'neutral_site': False,
#  'notes': None,
#  'season': 2022,
#  'season_type': 'regular',
#  'start_date': '2022-09-03T16:00:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'Kidd Brewer Stadium',
#  'venue_id': 3792,
#  'week': 1},
#  {'attendance': None,
#  'away_conference': 'CAA',
#  'away_division': 'fcs',
#  'away_id': 48,
#  'away_line_scores': [7, 0, 7, 0],
#  'away_points': 14,
#  'away_post_win_prob': 0.0957986021662971,
#  'away_postgame_elo': None,
#  'away_pregame_elo': None,
#  'away_team': 'Delaware',
#  'completed': True,
#  'conference_game': False,
#  'excitement_index': 7.841301814,
#  'highlights': None,
#  'home_conference': 'American Athletic',
#  'home_division': 'fbs',
#  'home_id': 2426,
#  'home_line_scores': [0, 0, 7, 0],
#  'home_points': 7,
#  'home_post_win_prob': 0.9042013978337029,
#  'home_postgame_elo': 1403,
#  'home_pregame_elo': 1403,
#  'home_team': 'Navy',
#  'id': 401415611,
#  'neutral_site': False,
#  'notes': None,
#  'season': 2022,
#  'season_type': 'regular',
#  'start_date': '2022-09-03T16:00:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'Navy-Marine Corps Memorial Stadium',
#  'venue_id': 3852,
#  'week': 1},
#  {'attendance': None,
#  'away_conference': 'Western Athletic',
#  'away_division': 'fcs',
#  'away_id': 2534,
#  'away_line_scores': [0, 0, 0, 0],
#  'away_points': 0,
#  'away_post_win_prob': 0.0019968448918086246,
#  'away_postgame_elo': None,
#  'away_pregame_elo': None,
#  'away_team': 'Sam Houston State',
#  'completed': True,
#  'conference_game': False,
#  'excitement_index': 1.3152998299,
#  'highlights': None,
#  'home_conference': 'SEC',
#  'home_division': 'fbs',
#  'home_id': 245,
#  'home_line_scores': [7, 10, 7, 7],
#  'home_points': 31,
#  'home_post_win_prob': 0.9980031551081914,
#  'home_postgame_elo': 1708,
#  'home_pregame_elo': 1708,
#  'home_team': 'Texas A&M',
#  'id': 401403865,
#  'neutral_site': False,
#  'notes': None,
#  'season': 2022,
#  'season_type': 'regular',
#  'start_date': '2022-09-03T16:00:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'Kyle Field',
#  'venue_id': 3795,
#  'week': 1},
#  {'attendance': None,
#  'away_conference': 'MVFC',
#  'away_division': 'fcs',
#  'away_id': 2571,
#  'away_line_scores': [0, 3, 0, 0],
#  'away_points': 3,
#  'away_post_win_prob': 0.19986848629847243,
#  'away_postgame_elo': None,
#  'away_pregame_elo': None,
#  'away_team': 'South Dakota State',
#  'completed': True,
#  'conference_game': False,
#  'excitement_index': 7.8988660279,
#  'highlights': None,
#  'home_conference': 'Big Ten',
#  'home_division': 'fbs',
#  'home_id': 2294,
#  'home_line_scores': [3, 0, 2, 2],
#  'home_points': 7,
#  'home_post_win_prob': 0.8001315137015276,
#  'home_postgame_elo': 1624,
#  'home_pregame_elo': 1624,
#  'home_team': 'Iowa',
#  'id': 401405062,
#  'neutral_site': False,
#  'notes': None,
#  'season': 2022,
#  'season_type': 'regular',
#  'start_date': '2022-09-03T16:00:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'Kinnick Stadium',
#  'venue_id': 3793,
#  'week': 1},
#  {'attendance': None,
#  'away_conference': 'Mid-American',
#  'away_division': 'fbs',
#  'away_id': 2084,
#  'away_line_scores': [0, 7, 0, 3],
#  'away_points': 10,
#  'away_post_win_prob': 0.0018396409884733345,
#  'away_postgame_elo': 1344,
#  'away_pregame_elo': 1382,
#  'away_team': 'Buffalo',
#  'completed': True,
#  'conference_game': False,
#  'excitement_index': 1.8374388254,
#  'highlights': None,
#  'home_conference': 'Big Ten',
#  'home_division': 'fbs',
#  'home_id': 120,
#  'home_line_scores': [7, 10, 7, 7],
#  'home_points': 31,
#  'home_post_win_prob': 0.9981603590115267,
#  'home_postgame_elo': 1534,
#  'home_pregame_elo': 1496,
#  'home_team': 'Maryland',
#  'id': 401405066,
#  'neutral_site': False,
#  'notes': None,
#  'season': 2022,
#  'season_type': 'regular',
#  'start_date': '2022-09-03T16:00:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'Maryland Stadium',
#  'venue_id': 3665,
#  'week': 1},
#  {'attendance': None,
#  'away_conference': 'Mountain West',
#  'away_division': 'fbs',
#  'away_id': 36,
#  'away_line_scores': [0, 0, 0, 7],
#  'away_points': 7,
#  'away_post_win_prob': 0.0016054143114814234,
#  'away_postgame_elo': 1329,
#  'away_pregame_elo': 1399,
#  'away_team': 'Colorado State',
#  'completed': True,
#  'conference_game': False,
#  'excitement_index': 1.1633229021,
#  'highlights': None,
#  'home_conference': 'Big Ten',
#  'home_division': 'fbs',
#  'home_id': 130,
#  'home_line_scores': [10, 13, 14, 14],
#  'home_points': 51,
#  'home_post_win_prob': 0.9983945856885186,
#  'home_postgame_elo': 1918,
#  'home_pregame_elo': 1848,
#  'home_team': 'Michigan',
#  'id': 401405067,
#  'neutral_site': False,
#  'notes': None,
#  'season': 2022,
#  'season_type': 'regular',
#  'start_date': '2022-09-03T16:00:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'Michigan Stadium',
#  'venue_id': 3558,
#  'week': 1},
#  {'attendance': None,
#  'away_conference': 'Big Ten',
#  'away_division': 'fbs',
#  'away_id': 164,
#  'away_line_scores': [0, 6, 9, 7],
#  'away_points': 22,
#  'away_post_win_prob': 0.7507451179308453,
#  'away_postgame_elo': 1370,
#  'away_pregame_elo': 1365,
#  'away_team': 'Rutgers',
#  'completed': True,
#  'conference_game': False,
#  'excitement_index': 4.8580219149,
#  'highlights': None,
#  'home_conference': 'ACC',
#  'home_division': 'fbs',
#  'home_id': 103,
#  'home_line_scores': [7, 7, 7, 0],
#  'home_points': 21,
#  'home_post_win_prob': 0.24925488206915467,
#  'home_postgame_elo': 1438,
#  'home_pregame_elo': 1443,
#  'home_team': 'Boston College',
#  'id': 401405069,
#  'neutral_site': False,
#  'notes': None,
#  'season': 2022,
#  'season_type': 'regular',
#  'start_date': '2022-09-03T16:00:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'Alumni Stadium',
#  'venue_id': 3615,
#  'week': 1},
#  {'attendance': None,
#  'away_conference': 'CAA',
#  'away_division': 'fcs',
#  'away_id': 257,
#  'away_line_scores': [7, 3, 7, 0],
#  'away_points': 17,
#  'away_post_win_prob': 0.0017394258231459014,
#  'away_postgame_elo': None,
#  'away_pregame_elo': None,
#  'away_team': 'Richmond',
#  'completed': True,
#  'conference_game': False,
#  'excitement_index': 2.2408137378,
#  'highlights': None,
#  'home_conference': 'ACC',
#  'home_division': 'fbs',
#  'home_id': 258,
#  'home_line_scores': [14, 14, 0, 6],
#  'home_points': 34,
#  'home_post_win_prob': 0.9982605741768541,
#  'home_postgame_elo': 1526,
#  'home_pregame_elo': 1526,
#  'home_team': 'Virginia',
#  'id': 401411100,
#  'neutral_site': False,
#  'notes': None,
#  'season': 2022,
#  'season_type': 'regular',
#  'start_date': '2022-09-03T16:30:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'Scott Stadium',
#  'venue_id': 3923,
#  'week': 1},
#  {'attendance': None,
#  'away_conference': 'MVFC',
#  'away_division': 'fcs',
#  'away_id': 2460,
#  'away_line_scores': [3, 0, 0, 14],
#  'away_points': 17,
#  'away_post_win_prob': 0.0011030277181710568,
#  'away_postgame_elo': None,
#  'away_pregame_elo': None,
#  'away_team': 'Northern Iowa',
#  'completed': True,
#  'conference_game': False,
#  'excitement_index': 1.8930655481,
#  'highlights': None,
#  'home_conference': 'Mountain West',
#  'home_division': 'fbs',
#  'home_id': 2005,
#  'home_line_scores': [14, 13, 14, 7],
#  'home_points': 48,
#  'home_post_win_prob': 0.9988969722818289,
#  'home_postgame_elo': 1650,
#  'home_pregame_elo': 1650,
#  'home_team': 'Air Force',
#  'id': 401415209,
#  'neutral_site': False,
#  'notes': None,
#  'season': 2022,
#  'season_type': 'regular',
#  'start_date': '2022-09-03T17:00:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'Falcon Stadium',
#  'venue_id': 3713,
#  'week': 1},
#  {'attendance': None,
#  'away_conference': 'OVC',
#  'away_division': 'fcs',
#  'away_id': 2546,
#  'away_line_scores': [0, 10, 0, 0],
#  'away_points': 10,
#  'away_post_win_prob': 0.0021836968455826167,
#  'away_postgame_elo': None,
#  'away_pregame_elo': None,
#  'away_team': 'Southeast Missouri State',
#  'completed': True,
#  'conference_game': False,
#  'excitement_index': 1.507519994,
#  'highlights': None,
#  'home_conference': 'Big 12',
#  'home_division': 'fbs',
#  'home_id': 66,
#  'home_line_scores': [7, 14, 7, 14],
#  'home_points': 42,
#  'home_post_win_prob': 0.9978163031544174,
#  'home_postgame_elo': 1779,
#  'home_pregame_elo': 1779,
#  'home_team': 'Iowa State',
#  'id': 401404057,
#  'neutral_site': False,
#  'notes': None,
#  'season': 2022,
#  'season_type': 'regular',
#  'start_date': '2022-09-03T18:00:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'Jack Trice Stadium',
#  'venue_id': 3772,
#  'week': 1},
#  {'attendance': None,
#  'away_conference': 'Mid-American',
#  'away_division': 'fbs',
#  'away_id': 189,
#  'away_line_scores': [10, 7, 0, 0],
#  'away_points': 17,
#  'away_post_win_prob': 0.002639175555022244,
#  'away_postgame_elo': 1187,
#  'away_pregame_elo': 1210,
#  'away_team': 'Bowling Green',
#  'completed': True,
#  'conference_game': False,
#  'excitement_index': 3.3311599769,
#  'highlights': None,
#  'home_conference': 'Pac-12',
#  'home_division': 'fbs',
#  'home_id': 26,
#  'home_line_scores': [7, 17, 7, 14],
#  'home_points': 45,
#  'home_post_win_prob': 0.9973608244449778,
#  'home_postgame_elo': 1690,
#  'home_pregame_elo': 1667,
#  'home_team': 'UCLA',
#  'id': 401403971,
#  'neutral_site': False,
#  'notes': None,
#  'season': 2022,
#  'season_type': 'regular',
#  'start_date': '2022-09-03T18:30:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'Rose Bowl',
#  'venue_id': 1056,
#  'week': 1},
#  {'attendance': None,
#  'away_conference': 'Pac-12',
#  'away_division': 'fbs',
#  'away_id': 12,
#  'away_line_scores': [10, 14, 7, 7],
#  'away_points': 38,
#  'away_post_win_prob': 0.9420068717729074,
#  'away_postgame_elo': 1377,
#  'away_pregame_elo': 1306,
#  'away_team': 'Arizona',
#  'completed': True,
#  'conference_game': False,
#  'excitement_index': 3.767920909,
#  'highlights': None,
#  'home_conference': 'Mountain West',
#  'home_division': 'fbs',
#  'home_id': 21,
#  'home_line_scores': [0, 10, 10, 0],
#  'home_points': 20,
#  'home_post_win_prob': 0.05799312822709257,
#  'home_postgame_elo': 1464,
#  'home_pregame_elo': 1535,
#  'home_team': 'San Diego State',
#  'id': 401403967,
#  'neutral_site': False,
#  'notes': None,
#  'season': 2022,
#  'season_type': 'regular',
#  'start_date': '2022-09-03T19:30:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'Snapdragon Stadium',
#  'venue_id': 7311,
#  'week': 1},
#  {'attendance': None,
#  'away_conference': 'American Athletic',
#  'away_division': 'fbs',
#  'away_id': 202,
#  'away_line_scores': [3, 17, 7, 7, 3, 0],
#  'away_points': 37,
#  'away_post_win_prob': 0.11826216236466691,
#  'away_postgame_elo': 1500,
#  'away_pregame_elo': 1502,
#  'away_team': 'Tulsa',
#  'completed': True,
#  'conference_game': False,
#  'excitement_index': 8.4642633492,
#  'highlights': None,
#  'home_conference': 'Mountain West',
#  'home_division': 'fbs',
#  'home_id': 2751,
#  'home_line_scores': [10, 7, 7, 10, 3, 3],
#  'home_points': 40,
#  'home_post_win_prob': 0.8817378376353331,
#  'home_postgame_elo': 1411,
#  'home_pregame_elo': 1409,
#  'home_team': 'Wyoming',
#  'id': 401415211,
#  'neutral_site': False,
#  'notes': None,
#  'season': 2022,
#  'season_type': 'regular',
#  'start_date': '2022-09-03T19:30:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'War Memorial Stadium',
#  'venue_id': 3984,
#  'week': 1},
#  {'attendance': None,
#  'away_conference': 'Conference USA',
#  'away_division': 'fbs',
#  'away_id': 2638,
#  'away_line_scores': [0, 10, 0, 3],
#  'away_points': 13,
#  'away_post_win_prob': 0.0010661907019267058,
#  'away_postgame_elo': 1286,
#  'away_pregame_elo': 1323,
#  'away_team': 'UTEP',
#  'completed': True,
#  'conference_game': False,
#  'excitement_index': 1.193939711,
#  'highlights': None,
#  'home_conference': 'Big 12',
#  'home_division': 'fbs',
#  'home_id': 201,
#  'home_line_scores': [21, 7, 14, 3],
#  'home_points': 45,
#  'home_post_win_prob': 0.9989338092980733,
#  'home_postgame_elo': 1786,
#  'home_pregame_elo': 1749,
#  'home_team': 'Oklahoma',
#  'id': 401426541,
#  'neutral_site': False,
#  'notes': None,
#  'season': 2022,
#  'season_type': 'regular',
#  'start_date': '2022-09-03T19:30:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'Gaylord Family Oklahoma Memorial Stadium',
#  'venue_id': 3835,
#  'week': 1},
#  {'attendance': None,
#  'away_conference': 'MVFC',
#  'away_division': 'fcs',
#  'away_id': 155,
#  'away_line_scores': [0, 7, 10, 0],
#  'away_points': 17,
#  'away_post_win_prob': 0.002602946581768406,
#  'away_postgame_elo': None,
#  'away_pregame_elo': None,
#  'away_team': 'North Dakota',
#  'completed': True,
#  'conference_game': False,
#  'excitement_index': 2.9079307486,
#  'highlights': None,
#  'home_conference': 'Big Ten',
#  'home_division': 'fbs',
#  'home_id': 158,
#  'home_line_scores': [7, 0, 17, 14],
#  'home_points': 38,
#  'home_post_win_prob': 0.9973970534182316,
#  'home_postgame_elo': 1623,
#  'home_pregame_elo': 1623,
#  'home_team': 'Nebraska',
#  'id': 401405063,
#  'neutral_site': False,
#  'notes': None,
#  'season': 2022,
#  'season_type': 'regular',
#  'start_date': '2022-09-03T19:30:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'Memorial Stadium',
#  'venue_id': 3834,
#  'week': 1},
#  {'attendance': None,
#  'away_conference': 'Pac-12',
#  'away_division': 'fbs',
#  'away_id': 2483,
#  'away_line_scores': [0, 3, 0, 0],
#  'away_points': 3,
#  'away_post_win_prob': 0.0036656798160673012,
#  'away_postgame_elo': 1484,
#  'away_pregame_elo': 1574,
#  'away_team': 'Oregon',
#  'completed': True,
#  'conference_game': False,
#  'excitement_index': 1.9145127895,
#  'highlights': None,
#  'home_conference': 'SEC',
#  'home_division': 'fbs',
#  'home_id': 61,
#  'home_line_scores': [7, 21, 14, 7],
#  'home_points': 49,
#  'home_post_win_prob': 0.9963343201839328,
#  'home_postgame_elo': 2070,
#  'home_pregame_elo': 1980,
#  'home_team': 'Georgia',
#  'id': 401403858,
#  'neutral_site': True,
#  'notes': 'Chick-fil-A Kickoff',
#  'season': 2022,
#  'season_type': 'regular',
#  'start_date': '2022-09-03T19:30:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'Mercedes-Benz Stadium',
#  'venue_id': 5348,
#  'week': 1},
#  {'attendance': None,
#  'away_conference': 'American Athletic',
#  'away_division': 'fbs',
#  'away_id': 2132,
#  'away_line_scores': [0, 0, 17, 7],
#  'away_points': 24,
#  'away_post_win_prob': 0.16666025253701355,
#  'away_postgame_elo': 1781,
#  'away_pregame_elo': 1801,
#  'away_team': 'Cincinnati',
#  'completed': True,
#  'conference_game': False,
#  'excitement_index': 5.6882250154,
#  'highlights': None,
#  'home_conference': 'SEC',
#  'home_division': 'fbs',
#  'home_id': 8,
#  'home_line_scores': [7, 7, 10, 7],
#  'home_points': 31,
#  'home_post_win_prob': 0.8333397474629864,
#  'home_postgame_elo': 1646,
#  'home_pregame_elo': 1626,
#  'home_team': 'Arkansas',
#  'id': 401403855,
#  'neutral_site': False,
#  'notes': None,
#  'season': 2022,
#  'season_type': 'regular',
#  'start_date': '2022-09-03T19:30:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'Donald W. Reynolds Razorback Stadium Frank Broyles Field',
#  'venue_id': 3887,
#  'week': 1},
#  {'attendance': None,
#  'away_conference': 'MEAC',
#  'away_division': 'fcs',
#  'away_id': 2450,
#  'away_line_scores': [0, 0, 3, 0],
#  'away_points': 3,
#  'away_post_win_prob': None,
#  'away_postgame_elo': None,
#  'away_pregame_elo': None,
#  'away_team': 'Norfolk State',
#  'completed': True,
#  'conference_game': False,
#  'excitement_index': None,
#  'highlights': None,
#  'home_conference': 'Sun Belt',
#  'home_division': 'fbs',
#  'home_id': 276,
#  'home_line_scores': [10, 28, 17, 0],
#  'home_points': 55,
#  'home_post_win_prob': None,
#  'home_postgame_elo': 1548,
#  'home_pregame_elo': 1548,
#  'home_team': 'Marshall',
#  'id': 401415015,
#  'neutral_site': False,
#  'notes': None,
# ...
#  'venue_id': 477,
#  'week': 13},
#  {'attendance': None,
#  'away_conference': 'ACC',
#  'away_division': 'fbs',
#  'away_id': 221,
#  'away_line_scores': [14, 14, 7, 7],
#  'away_points': 42,
#  'away_post_win_prob': 0.997853888286159,
#  'away_postgame_elo': 1688,
#  'away_pregame_elo': 1653,
#  'away_team': 'Pittsburgh',
#  'completed': True,
#  'conference_game': True,
#  'excitement_index': 2.1346924409,
#  'highlights': None,
#  'home_conference': 'ACC',
#  'home_division': 'fbs',
#  'home_id': 2390,
#  'home_line_scores': [0, 0, 3, 13],
#  'home_points': 16,
#  'home_post_win_prob': 0.002146111713841035,
#  'home_postgame_elo': 1316,
#  'home_pregame_elo': 1351,
#  'home_team': 'Miami',
#  'id': 401411175,
#  'neutral_site': False,
#  'notes': None,
#  'season': 2022,
#  'season_type': 'regular',
#  'start_date': '2022-11-27T01:00:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'Hard Rock Stadium',
#  'venue_id': 3948,
#  'week': 13},
#  {'attendance': None,
#  'away_conference': 'Big 12',
#  'away_division': 'fbs',
#  'away_id': 2305,
#  'away_line_scores': [7, 14, 0, 6],
#  'away_points': 27,
#  'away_post_win_prob': 0.061391739866205275,
#  'away_postgame_elo': 1366,
#  'away_pregame_elo': 1364,
#  'away_team': 'Kansas',
#  'completed': True,
#  'conference_game': True,
#  'excitement_index': 3.184190764,
#  'highlights': None,
#  'home_conference': 'Big 12',
#  'home_division': 'fbs',
#  'home_id': 2306,
#  'home_line_scores': [23, 7, 7, 10],
#  'home_points': 47,
#  'home_post_win_prob': 0.9386082601337947,
#  'home_postgame_elo': 1892,
#  'home_pregame_elo': 1894,
#  'home_team': 'Kansas State',
#  'id': 401404121,
#  'neutral_site': False,
#  'notes': None,
#  'season': 2022,
#  'season_type': 'regular',
#  'start_date': '2022-11-27T01:00:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'Bill Snyder Family Football Stadium',
#  'venue_id': 3636,
#  'week': 13},
#  {'attendance': None,
#  'away_conference': 'Mountain West',
#  'away_division': 'fbs',
#  'away_id': 2005,
#  'away_line_scores': [7, 0, 3, 3],
#  'away_points': 13,
#  'away_post_win_prob': 0.9974808275854671,
#  'away_postgame_elo': 1731,
#  'away_pregame_elo': 1731,
#  'away_team': 'Air Force',
#  'completed': True,
#  'conference_game': True,
#  'excitement_index': 3.1602420508,
#  'highlights': None,
#  'home_conference': 'Mountain West',
#  'home_division': 'fbs',
#  'home_id': 21,
#  'home_line_scores': [0, 0, 3, 0],
#  'home_points': 3,
#  'home_post_win_prob': 0.002519172414532972,
#  'home_postgame_elo': 1487,
#  'home_pregame_elo': 1487,
#  'home_team': 'San Diego State',
#  'id': 401415267,
#  'neutral_site': False,
#  'notes': None,
#  'season': 2022,
#  'season_type': 'regular',
#  'start_date': '2022-11-27T02:00:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'Snapdragon Stadium',
#  'venue_id': 7311,
#  'week': 13},
#  {'attendance': None,
#  'away_conference': 'Pac-12',
#  'away_division': 'fbs',
#  'away_id': 264,
#  'away_line_scores': [7, 21, 7, 16],
#  'away_points': 51,
#  'away_post_win_prob': 0.9988139034904467,
#  'away_postgame_elo': 1729,
#  'away_pregame_elo': 1684,
#  'away_team': 'Washington',
#  'completed': True,
#  'conference_game': True,
#  'excitement_index': 5.5816190637,
#  'highlights': None,
#  'home_conference': 'Pac-12',
#  'home_division': 'fbs',
#  'home_id': 265,
#  'home_line_scores': [10, 17, 6, 0],
#  'home_points': 33,
#  'home_post_win_prob': 0.0011860965095532832,
#  'home_postgame_elo': 1644,
#  'home_pregame_elo': 1689,
#  'home_team': 'Washington State',
#  'id': 401404051,
#  'neutral_site': False,
#  'notes': None,
#  'season': 2022,
#  'season_type': 'regular',
#  'start_date': '2022-11-27T03:30:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'Martin Stadium',
#  'venue_id': 3820,
#  'week': 13},
#  {'attendance': None,
#  'away_conference': 'FBS Independents',
#  'away_division': 'fbs',
#  'away_id': 252,
#  'away_line_scores': [14, 14, 0, 7],
#  'away_points': 35,
#  'away_post_win_prob': 0.9984403905516734,
#  'away_postgame_elo': 1524,
#  'away_pregame_elo': 1529,
#  'away_team': 'BYU',
#  'completed': True,
#  'conference_game': False,
#  'excitement_index': 2.123668114,
#  'highlights': None,
#  'home_conference': 'Pac-12',
#  'home_division': 'fbs',
#  'home_id': 24,
#  'home_line_scores': [3, 9, 0, 14],
#  'home_points': 26,
#  'home_post_win_prob': 0.0015596094483265655,
#  'home_postgame_elo': 1237,
#  'home_pregame_elo': 1232,
#  'home_team': 'Stanford',
#  'id': 401404049,
#  'neutral_site': False,
#  'notes': None,
#  'season': 2022,
#  'season_type': 'regular',
#  'start_date': '2022-11-27T04:00:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'Stanford Stadium',
#  'venue_id': 3940,
#  'week': 13},
#  {'attendance': None,
#  'away_conference': 'Mid-American',
#  'away_division': 'fbs',
#  'away_id': 2006,
#  'away_line_scores': [9, 7, 0, 6],
#  'away_points': 22,
#  'away_post_win_prob': None,
#  'away_postgame_elo': 1154,
#  'away_pregame_elo': 1147,
#  'away_team': 'Akron',
#  'completed': True,
#  'conference_game': True,
#  'excitement_index': None,
#  'highlights': None,
#  'home_conference': 'Mid-American',
#  'home_division': 'fbs',
#  'home_id': 2084,
#  'home_line_scores': [0, 10, 7, 6],
#  'home_points': 23,
#  'home_post_win_prob': None,
#  'home_postgame_elo': 1382,
#  'home_pregame_elo': 1389,
#  'home_team': 'Buffalo',
#  'id': 401506450,
#  'neutral_site': False,
#  'notes': None,
#  'season': 2022,
#  'season_type': 'regular',
#  'start_date': '2022-12-02T18:00:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'UB Stadium',
#  'venue_id': 3965,
#  'week': 14},
#  {'attendance': None,
#  'away_conference': 'Conference USA',
#  'away_division': 'fbs',
#  'away_id': 249,
#  'away_line_scores': [7, 3, 10, 7],
#  'away_points': 27,
#  'away_post_win_prob': 0.019837625055171837,
#  'away_postgame_elo': 1453,
#  'away_pregame_elo': 1487,
#  'away_team': 'North Texas',
#  'completed': True,
#  'conference_game': True,
#  'excitement_index': 4.0963967698,
#  'highlights': None,
#  'home_conference': 'Conference USA',
#  'home_division': 'fbs',
#  'home_id': 2636,
#  'home_line_scores': [7, 17, 10, 14],
#  'home_points': 48,
#  'home_post_win_prob': 0.9801623749448282,
#  'home_postgame_elo': 1679,
#  'home_pregame_elo': 1645,
#  'home_team': 'UT San Antonio',
#  'id': 401437032,
#  'neutral_site': False,
#  'notes': 'Conference USA Championship',
#  'season': 2022,
#  'season_type': 'regular',
#  'start_date': '2022-12-03T00:30:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'Alamodome',
#  'venue_id': 3604,
#  'week': 14},
#  {'attendance': None,
#  'away_conference': 'Pac-12',
#  'away_division': 'fbs',
#  'away_id': 254,
#  'away_line_scores': [3, 14, 7, 23],
#  'away_points': 47,
#  'away_post_win_prob': 0.994304119114533,
#  'away_postgame_elo': 1936,
#  'away_pregame_elo': 1896,
#  'away_team': 'Utah',
#  'completed': True,
#  'conference_game': True,
#  'excitement_index': 5.1850225387,
#  'highlights': None,
#  'home_conference': 'Pac-12',
#  'home_division': 'fbs',
#  'home_id': 30,
#  'home_line_scores': [14, 3, 0, 7],
#  'home_points': 24,
#  'home_post_win_prob': 0.005695880885467043,
#  'home_postgame_elo': 1745,
#  'home_pregame_elo': 1785,
#  'home_team': 'USC',
#  'id': 401437035,
#  'neutral_site': True,
#  'notes': 'Pac-12 Championship Game',
#  'season': 2022,
#  'season_type': 'regular',
#  'start_date': '2022-12-03T01:00:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'Allegiant Stadium',
#  'venue_id': 6501,
#  'week': 14},
#  {'attendance': None,
#  'away_conference': 'Big 12',
#  'away_division': 'fbs',
#  'away_id': 2306,
#  'away_line_scores': [7, 7, 7, 7, 3],
#  'away_points': 31,
#  'away_post_win_prob': 0.6584641462426883,
#  'away_postgame_elo': 1891,
#  'away_pregame_elo': 1892,
#  'away_team': 'Kansas State',
#  'completed': True,
#  'conference_game': True,
#  'excitement_index': 8.7438443065,
#  'highlights': None,
#  'home_conference': 'Big 12',
#  'home_division': 'fbs',
#  'home_id': 2628,
#  'home_line_scores': [7, 3, 7, 11, 0],
#  'home_points': 28,
#  'home_post_win_prob': 0.3415358537573116,
#  'home_postgame_elo': 1856,
#  'home_pregame_elo': 1855,
#  'home_team': 'TCU',
#  'id': 401437030,
#  'neutral_site': True,
#  'notes': 'Dr Pepper Big 12 Championship',
#  'season': 2022,
#  'season_type': 'regular',
#  'start_date': '2022-12-03T17:00:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'AT&T Stadium',
#  'venue_id': 3687,
#  'week': 14},
#  {'attendance': None,
#  'away_conference': 'Mid-American',
#  'away_division': 'fbs',
#  'away_id': 2649,
#  'away_line_scores': [7, 3, 0, 7],
#  'away_points': 17,
#  'away_post_win_prob': 0.9750253830752021,
#  'away_postgame_elo': 1494,
#  'away_pregame_elo': 1478,
#  'away_team': 'Toledo',
#  'completed': True,
#  'conference_game': True,
#  'excitement_index': 5.5028031694,
#  'highlights': None,
#  'home_conference': 'Mid-American',
#  'home_division': 'fbs',
#  'home_id': 195,
#  'home_line_scores': [0, 7, 0, 0],
#  'home_points': 7,
#  'home_post_win_prob': 0.024974616924797854,
#  'home_postgame_elo': 1479,
#  'home_pregame_elo': 1495,
#  'home_team': 'Ohio',
#  'id': 401437033,
#  'neutral_site': True,
#  'notes': 'MAC Championship',
#  'season': 2022,
#  'season_type': 'regular',
#  'start_date': '2022-12-03T17:00:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'Ford Field',
#  'venue_id': 3727,
#  'week': 14},
#  {'attendance': None,
#  'away_conference': 'Pioneer',
#  'away_division': 'fcs',
#  'away_id': 2674,
#  'away_line_scores': [0, 3, 0, 0],
#  'away_points': 3,
#  'away_post_win_prob': 0.0010301519494402278,
#  'away_postgame_elo': None,
#  'away_pregame_elo': None,
#  'away_team': 'Valparaiso',
#  'completed': True,
#  'conference_game': False,
#  'excitement_index': 2.4151946784,
#  'highlights': None,
#  'home_conference': 'FBS Independents',
#  'home_division': 'fbs',
#  'home_id': 166,
#  'home_line_scores': [21, 14, 17, 13],
#  'home_points': 65,
#  'home_post_win_prob': 0.9989698480505598,
#  'home_postgame_elo': None,
#  'home_pregame_elo': None,
#  'home_team': 'New Mexico State',
#  'id': 401507088,
#  'neutral_site': False,
#  'notes': None,
#  'season': 2022,
#  'season_type': 'regular',
#  'start_date': '2022-12-03T20:00:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'Aggie Memorial Stadium',
#  'venue_id': 3601,
#  'week': 14},
#  {'attendance': None,
#  'away_conference': 'Sun Belt',
#  'away_division': 'fbs',
#  'away_id': 324,
#  'away_line_scores': [0, 7, 6, 13],
#  'away_points': 26,
#  'away_post_win_prob': 0.010491199061217649,
#  'away_postgame_elo': 1408,
#  'away_pregame_elo': 1443,
#  'away_team': 'Coastal Carolina',
#  'completed': True,
#  'conference_game': True,
#  'excitement_index': 2.0451976774,
#  'highlights': None,
#  'home_conference': 'Sun Belt',
#  'home_division': 'fbs',
#  'home_id': 2653,
#  'home_line_scores': [17, 14, 14, 0],
#  'home_points': 45,
#  'home_post_win_prob': 0.9895088009387824,
#  'home_postgame_elo': 1564,
#  'home_pregame_elo': 1529,
#  'home_team': 'Troy',
#  'id': 401437037,
#  'neutral_site': False,
#  'notes': 'Sun Belt Championship',
#  'season': 2022,
#  'season_type': 'regular',
#  'start_date': '2022-12-03T20:30:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'Veterans Memorial Stadium',
#  'venue_id': 3975,
#  'week': 14},
#  {'attendance': None,
#  'away_conference': 'SEC',
#  'away_division': 'fbs',
#  'away_id': 99,
#  'away_line_scores': [7, 3, 13, 7],
#  'away_points': 30,
#  'away_post_win_prob': 0.0055291534035121215,
#  'away_postgame_elo': 1715,
#  'away_pregame_elo': 1729,
#  'away_team': 'LSU',
#  'completed': True,
#  'conference_game': True,
#  'excitement_index': 2.2826295001,
#  'highlights': None,
#  'home_conference': 'SEC',
#  'home_division': 'fbs',
#  'home_id': 61,
#  'home_line_scores': [14, 21, 7, 8],
#  'home_points': 50,
#  'home_post_win_prob': 0.9944708465964879,
#  'home_postgame_elo': 2146,
#  'home_pregame_elo': 2132,
#  'home_team': 'Georgia',
#  'id': 401437036,
#  'neutral_site': True,
#  'notes': 'SEC Championship Game',
#  'season': 2022,
#  'season_type': 'regular',
#  'start_date': '2022-12-03T21:00:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'Mercedes-Benz Stadium',
#  'venue_id': 5348,
#  'week': 14},
#  {'attendance': None,
#  'away_conference': 'American Athletic',
#  'away_division': 'fbs',
#  'away_id': 2116,
#  'away_line_scores': [0, 7, 7, 14],
#  'away_points': 28,
#  'away_post_win_prob': 0.0016200960789962693,
#  'away_postgame_elo': 1612,
#  'away_pregame_elo': 1647,
#  'away_team': 'UCF',
#  'completed': True,
#  'conference_game': True,
#  'excitement_index': 5.1121753652,
#  'highlights': None,
#  'home_conference': 'American Athletic',
#  'home_division': 'fbs',
#  'home_id': 2655,
#  'home_line_scores': [10, 7, 7, 21],
#  'home_points': 45,
#  'home_post_win_prob': 0.9983799039210037,
#  'home_postgame_elo': 1710,
#  'home_pregame_elo': 1675,
#  'home_team': 'Tulane',
#  'id': 401437008,
#  'neutral_site': False,
#  'notes': 'American Athletic Championship',
#  'season': 2022,
#  'season_type': 'regular',
#  'start_date': '2022-12-03T21:00:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'Benson Field at Yulman Stadium',
#  'venue_id': 4729,
#  'week': 14},
#  {'attendance': None,
#  'away_conference': 'Mountain West',
#  'away_division': 'fbs',
#  'away_id': 278,
#  'away_line_scores': [0, 14, 0, 14],
#  'away_points': 28,
#  'away_post_win_prob': 0.7869688482495216,
#  'away_postgame_elo': 1709,
#  'away_pregame_elo': 1676,
#  'away_team': 'Fresno State',
#  'completed': True,
#  'conference_game': True,
#  'excitement_index': 5.2990938943,
#  'highlights': None,
#  'home_conference': 'Mountain West',
#  'home_division': 'fbs',
#  'home_id': 68,
#  'home_line_scores': [0, 6, 3, 7],
#  'home_points': 16,
#  'home_post_win_prob': 0.21303115175047832,
#  'home_postgame_elo': 1717,
#  'home_pregame_elo': 1750,
#  'home_team': 'Boise State',
#  'id': 401437034,
#  'neutral_site': False,
#  'notes': 'Mountain West Championship Game',
#  'season': 2022,
#  'season_type': 'regular',
#  'start_date': '2022-12-03T21:00:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'Albertsons Stadium',
#  'venue_id': 3653,
#  'week': 14},
#  {'attendance': None,
#  'away_conference': 'Big Ten',
#  'away_division': 'fbs',
#  'away_id': 2509,
#  'away_line_scores': [7, 6, 3, 6],
#  'away_points': 22,
#  'away_post_win_prob': 0.004846775054178298,
#  'away_postgame_elo': 1616,
#  'away_pregame_elo': 1622,
#  'away_team': 'Purdue',
#  'completed': True,
#  'conference_game': True,
#  'excitement_index': 3.5700466024,
#  'highlights': None,
#  'home_conference': 'Big Ten',
#  'home_division': 'fbs',
#  'home_id': 130,
#  'home_line_scores': [7, 7, 14, 15],
#  'home_points': 43,
#  'home_post_win_prob': 0.9951532249458217,
#  'home_postgame_elo': 2150,
#  'home_pregame_elo': 2144,
#  'home_team': 'Michigan',
#  'id': 401437031,
#  'neutral_site': True,
#  'notes': 'Big Ten Championship Game',
#  'season': 2022,
#  'season_type': 'regular',
#  'start_date': '2022-12-04T01:00:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'Lucas Oil Stadium',
#  'venue_id': 3812,
#  'week': 14},
#  {'attendance': None,
#  'away_conference': 'ACC',
#  'away_division': 'fbs',
#  'away_id': 228,
#  'away_line_scores': [14, 10, 15, 0],
#  'away_points': 39,
#  'away_post_win_prob': 0.9983985373827284,
#  'away_postgame_elo': 1866,
#  'away_pregame_elo': 1821,
#  'away_team': 'Clemson',
#  'completed': True,
#  'conference_game': True,
#  'excitement_index': 2.933245348,
#  'highlights': None,
#  'home_conference': 'ACC',
#  'home_division': 'fbs',
#  'home_id': 153,
#  'home_line_scores': [7, 3, 0, 0],
#  'home_points': 10,
#  'home_post_win_prob': 0.001601462617271544,
#  'home_postgame_elo': 1554,
#  'home_pregame_elo': 1599,
#  'home_team': 'North Carolina',
#  'id': 401437009,
#  'neutral_site': True,
#  'notes': 'Subway ACC Championship',
#  'season': 2022,
#  'season_type': 'regular',
#  'start_date': '2022-12-04T01:00:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'Bank of America Stadium',
#  'venue_id': 3628,
#  'week': 14},
#  {'attendance': None,
#  'away_conference': 'American Athletic',
#  'away_division': 'fbs',
#  'away_id': 2426,
#  'away_line_scores': [0, 3, 7, 0, 7, 0],
#  'away_points': 17,
#  'away_post_win_prob': 0.9647607373862503,
#  'away_postgame_elo': 1457,
#  'away_pregame_elo': 1462,
#  'away_team': 'Navy',
#  'completed': True,
#  'conference_game': False,
#  'excitement_index': 7.9335168303,
#  'highlights': None,
#  'home_conference': 'FBS Independents',
#  'home_division': 'fbs',
#  'home_id': 349,
#  'home_line_scores': [0, 7, 0, 3, 7, 3],
#  'home_points': 20,
#  'home_post_win_prob': 0.03523926261374963,
#  'home_postgame_elo': 1499,
#  'home_pregame_elo': 1494,
#  'home_team': 'Army',
#  'id': 401404145,
#  'neutral_site': True,
#  'notes': None,
#  'season': 2022,
#  'season_type': 'regular',
#  'start_date': '2022-12-10T20:00:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'Lincoln Financial Field',
#  'venue_id': 3806,
#  'week': 15}]
